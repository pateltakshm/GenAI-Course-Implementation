# %% [markdown]
# ### GenAI

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

# %%
llm= ChatOllama(
    model= "llama3.2:1b",
    temperature=0
)

# %%
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="Explain RAG to a dumb guy.")
]

# %%
result = llm.invoke(messages)
print(result.content)
# Out:
# I'm here to help you understand RAG in a way that's easy to grasp.
#
# RAG is an acronym that stands for "Red, Yellow, Green." It's a color-coding system used to categorize and manage different types of materials or tasks. Think of it like a simple inventory system.
#
# Imagine you have three boxes: Red, Yellow, and Green. Each box represents a different category:
#
# - **Red** is for items that need to be **REPAIRED** (fixed or replaced). These might include broken appliances, damaged furniture, or other things that can't be fixed.
# - **Yellow** is for items that need to be **MAINTAINED** (regularly checked and maintained). This could include things like light bulbs, air filters, or other routine tasks.
# - **Green** is for items that are in good condition and don't need any repairs or maintenance. These might include clean clothes, healthy food, or other things that are just fine.
#
# By using the RAG system, you can keep track of what needs to be done, what's already been done, and what still needs attention. It's a simple but effective way to manage your time and resources.

# %%
# !ollama pull bakllava
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling deb26e54cceb: 100% ▕██████████████████▏ 4.1 GB
# pulling addb9fdda3a5: 100% ▕██████████████████▏ 624 MB
# pulling d5ca8c59f62d: 100% ▕██████████████████▏   46 B
# pulling 17b7e63fbe77: 100% ▕██████████████████▏   51 B
# pulling b15ee2b77419: 100% ▕██████████████████▏  490 B
# verifying sha256 digest
# writing manifest
# success

# %%
import base64
from pathlib import Path

def encode_image(image_path: str) -> str:
    image_bytes= Path(image_path).read_bytes()
    return base64.b64encode(image_bytes).decode("utf-8")

image_b64 = encode_image("/Users/takshpatel/Desktop/GenAI-Course-Implementation/3. APIs/generated_image.png")

llm = ChatOllama(model= "bakllava",
                 temperature=0)

messages = HumanMessage(
    content=[
        {
        "type": "text",
        "text": "Describe the image in detail."
        },
        {
            "type": "image_url",
            "image_url": f"data:image/png;base64,{image_b64}"
        }

    ]
)

response = llm.invoke([messages])

print(response.content)
# Out:
#  The image features a large body of water, likely a lake, with mountains visible in the distance. The water's surface is calm and still, creating a perfect mirror image of the mountain range. There are several trees scattered around the scene, adding to the serene atmosphere. The reflection of the mountains on the lake, along with the presence of the trees, makes for a picturesque and tranquil setting.
